# %%
import os
import subprocess
import pandas as pd
from collections import defaultdict
import re

# %%
# ============================================================================
# CONFIGURATION
# ============================================================================
# Each query folder corresponds to a txt file
QUERY_CONFIGS = [
    {
        'query_folder': '/home/lead/notebooks/sol_up_pdb_files',  # Folder with PDB files (queries from sheet 1)
        'uniprot_txt': '/home/lead/notebooks/sol_up_ids.txt',      # Corresponding txt file with UniProt IDs
        'label': 'solubility_up'                              # Label for this query set
    },
    {
        'query_folder': '/home/lead/notebooks/sol_down_pdb_files',  # Folder with PDB files (queries from sheet 2)
        'uniprot_txt': '/home/lead/notebooks/sol_down_ids.txt',      # Corresponding txt file with UniProt IDs
        'label': 'solubility_down'                              # Label for this query set
    }
]

FOLDDISCO_INDEX = "/home/lead/notebooks/folddisco_index/index_murine_sk/index"  # Path to your Folddisco index
TOP_N = 50  # Number of top results to consider per query
THREADS = 4  # Number of threads for Folddisco
OUTPUT_DIR = "folddisco_results"  # Directory to store individual results

# %%
# ============================================================================
# SETUP
# ============================================================================

# Create output directory
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
# ============================================================================
# HELPER FUNCTIONS
# ============================================================================

def extract_uniprot_from_id(structure_id):
    """
    Extract UniProt ID from structure identifier.
    Handles formats like: AF-P09813-F1-model_v4.pdb or P09813_*.pdb
    """
    # Try pattern: AF-UNIPROT-*
    match = re.search(r'AF-([A-Z0-9]+)-', structure_id)
    if match:
        return match.group(1)
    
    # Try pattern: UNIPROT_*
    match = re.search(r'([A-Z0-9]+)_', structure_id)
    if match:
        return match.group(1)
    
    # Try pattern: just the uniprot ID
    match = re.search(r'([A-Z][0-9][A-Z0-9]{3,}[0-9])', structure_id)
    if match:
        return match.group(1)
    
    return None

def load_uniprot_ids(txt_file):
    """Load UniProt IDs from a text file."""
    with open(txt_file, 'r') as f:
        return set([line.strip() for line in f if line.strip()])

def run_folddisco_query(query_pdb, output_file):
    """
    Run Folddisco query for a single PDB file.
    """
    cmd = [
        "folddisco", "query",
        "-i", FOLDDISCO_INDEX,
        "-p", query_pdb,
        "-t", str(THREADS),
        "--per-structure",
        "--sort-by-score",
        "--header",
        "--skip-match"
    ]
    
    try:
        with open(output_file, 'w') as f:
            result = subprocess.run(cmd, stdout=f, stderr=subprocess.PIPE, text=True)
        
        if result.returncode != 0:
            print(f"  ERROR: {result.stderr}")
            return False
        return True
    except Exception as e:
        print(f"  ERROR running Folddisco: {e}")
        return False

def parse_folddisco_output(output_file, top_n, uniprot_ids_set):
    """
    Parse Folddisco output and return top N results with UniProt IDs.
    """
    try:
        df = pd.read_csv(output_file, sep='\t')
        
        # Take top N results
        df_top = df.head(top_n).copy()
        
        # Extract UniProt IDs from structure identifiers
        df_top['uniprot_id'] = df_top['id'].apply(extract_uniprot_from_id)
        
        # Filter to only those in our UniProt list
        df_filtered = df_top[df_top['uniprot_id'].isin(uniprot_ids_set)]
        
        return df_filtered
    except Exception as e:
        print(f"  ERROR parsing output: {e}")
        return pd.DataFrame()

# %%
# ============================================================================
# MAIN PROCESSING
# ============================================================================

# Storage for results across all datasets
all_results = []
query_summary = defaultdict(lambda: defaultdict(lambda: defaultdict(int)))

# Process each query configuration (folder + txt file pair)
for config_idx, config in enumerate(QUERY_CONFIGS, 1):
    query_folder = config['query_folder']
    uniprot_txt = config['uniprot_txt']
    label = config['label']
    
    print("="*70)
    print(f"PROCESSING CONFIGURATION {config_idx}/{len(QUERY_CONFIGS)}: {label}")
    print("="*70)
    print(f"Query folder: {query_folder}")
    print(f"UniProt file: {uniprot_txt}")
    
    # Load UniProt IDs for this dataset
    uniprot_ids_set = load_uniprot_ids(uniprot_txt)
    print(f"Loaded {len(uniprot_ids_set)} UniProt IDs\n")
    
    # Get all PDB files in query directory
    query_pdbs = [f for f in os.listdir(query_folder) 
                  if f.endswith('.pdb') and os.path.isfile(os.path.join(query_folder, f))]
    
    print(f"Found {len(query_pdbs)} query PDB files\n")
    
    # Create subdirectory for this dataset's results
    dataset_output_dir = os.path.join(OUTPUT_DIR, label)
    os.makedirs(dataset_output_dir, exist_ok=True)
    
    # Process each query PDB
    for i, pdb_file in enumerate(query_pdbs, 1):
        query_path = os.path.join(query_folder, pdb_file)
        output_file = os.path.join(dataset_output_dir, f"{pdb_file}.tsv")
        
        print(f"[{i}/{len(query_pdbs)}] Processing: {pdb_file}")
        
        # Extract query UniProt ID
        query_uniprot = extract_uniprot_from_id(pdb_file)
        
        # Run Folddisco
        if run_folddisco_query(query_path, output_file):
            print(f"  ✓ Query complete")
            
            # Parse results
            df_matches = parse_folddisco_output(output_file, TOP_N, uniprot_ids_set)
            
            print(f"  ✓ Found {len(df_matches)} matches in UniProt list")
            
            # Tally the matches
            for _, row in df_matches.iterrows():
                target_uniprot = row['uniprot_id']
                query_summary[label][query_uniprot][target_uniprot] += 1
                
                # Store detailed result
                all_results.append({
                    'dataset': label,
                    'query_pdb': pdb_file,
                    'query_uniprot': query_uniprot,
                    'target_uniprot': target_uniprot,
                    'target_structure': row['id'],
                    'idf_score': row['idf_score'],
                    'min_rmsd': row['min_rmsd'],
                    'max_node_cov': row['max_node_cov'],
                    'uniprot_source': uniprot_txt
                })
        else:
            print(f"  ✗ Query failed")
        
        print()
# Out:
# ======================================================================
# PROCESSING CONFIGURATION 1/2: solubility_up
# ======================================================================
# Query folder: /home/lead/notebooks/sol_up_pdb_files
# UniProt file: /home/lead/notebooks/sol_up_ids.txt
# Loaded 274 UniProt IDs
#
# Found 259 query PDB files
#
# [1/259] Processing: AF-Q8CGY6-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [2/259] Processing: AF-Q99JX3-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [3/259] Processing: AF-Q8C0L9-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [4/259] Processing: AF-Q9JK48-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [5/259] Processing: AF-Q921M7-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 1 matches in UniProt list
#
# [6/259] Processing: AF-O35344-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [7/259] Processing: AF-P28665-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [8/259] Processing: AF-Q9JKV1-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [9/259] Processing: AF-Q9Z239-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [10/259] Processing: AF-O09110-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [11/259] Processing: AF-Q8BJF9-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [12/259] Processing: AF-O08547-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [13/259] Processing: AF-Q9QZH6-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [14/259] Processing: AF-Q99K82-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [15/259] Processing: AF-Q8C5Z9-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [16/259] Processing: AF-P07309-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [17/259] Processing: AF-P63073-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [18/259] Processing: AF-Q3UPL0-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [19/259] Processing: AF-Q6PFD9-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [20/259] Processing: AF-P16045-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [21/259] Processing: AF-Q8QZR5-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [22/259] Processing: AF-D3Z6H8-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [23/259] Processing: AF-Q9D9V3-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [24/259] Processing: AF-Q99JH8-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [25/259] Processing: AF-Q9DB20-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [26/259] Processing: AF-Q61584-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [27/259] Processing: AF-Q9CQK7-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [28/259] Processing: AF-P03930-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [29/259] Processing: AF-Q8BGS2-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [30/259] Processing: AF-Q9WVG6-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [31/259] Processing: AF-Q8BZJ7-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [32/259] Processing: AF-P22599-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [33/259] Processing: AF-Q03265-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [34/259] Processing: AF-P46414-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 1 matches in UniProt list
#
# [35/259] Processing: AF-Q9CYG7-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [36/259] Processing: AF-D3Z689-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [37/259] Processing: AF-Q9CR26-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [38/259] Processing: AF-P11499-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [39/259] Processing: AF-Q99PP9-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [40/259] Processing: AF-Q8BTS4-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [41/259] Processing: AF-Q6IRU5-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [42/259] Processing: AF-Q3THS6-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [43/259] Processing: AF-Q8VHD8-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [44/259] Processing: AF-Q00897-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [45/259] Processing: AF-P11588-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [46/259] Processing: AF-P62962-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [47/259] Processing: AF-Q06138-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 1 matches in UniProt list
#
# [48/259] Processing: AF-O08992-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [49/259] Processing: AF-Q9DCJ9-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [50/259] Processing: AF-P08074-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [51/259] Processing: AF-Q61830-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [52/259] Processing: AF-Q9D7J4-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [53/259] Processing: AF-Q9EQ06-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [54/259] Processing: AF-Q8C006-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [55/259] Processing: AF-P14069-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [56/259] Processing: AF-Q91YY4-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [57/259] Processing: AF-Q99KR7-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [58/259] Processing: AF-Q9D0F9-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [59/259] Processing: AF-Q80ZJ6-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [60/259] Processing: AF-Q8BX80-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [61/259] Processing: AF-Q9CZW4-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [62/259] Processing: AF-P83093-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 1 matches in UniProt list
#
# [63/259] Processing: AF-Q9D1X0-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [64/259] Processing: AF-Q6NSR8-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [65/259] Processing: AF-P28738-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 1 matches in UniProt list
#
# [66/259] Processing: AF-Q9D1Q6-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [67/259] Processing: AF-Q8CIN4-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 1 matches in UniProt list
#
# [68/259] Processing: AF-Q78JE5-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [69/259] Processing: AF-Q6PHN1-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [70/259] Processing: AF-Q91XD7-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [71/259] Processing: AF-Q64314-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [72/259] Processing: AF-P29391-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [73/259] Processing: AF-Q61599-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [74/259] Processing: AF-Q9QZ73-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [75/259] Processing: AF-Q8JZL3-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [76/259] Processing: AF-P56812-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [77/259] Processing: AF-P49817-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [78/259] Processing: AF-P14427-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [79/259] Processing: AF-P22892-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [80/259] Processing: AF-P63038-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [81/259] Processing: AF-P54728-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [82/259] Processing: AF-Q8K1E6-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [83/259] Processing: AF-Q9WV80-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [84/259] Processing: AF-P06151-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [85/259] Processing: AF-Q8BTZ7-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [86/259] Processing: AF-Q6P069-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [87/259] Processing: AF-Q9DBC7-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [88/259] Processing: AF-P42225-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [89/259] Processing: AF-Q9D6U8-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [90/259] Processing: AF-P49138-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [91/259] Processing: AF-Q8BT60-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [92/259] Processing: AF-Q91XD6-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [93/259] Processing: AF-Q8BJ03-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [94/259] Processing: AF-Q9CQC6-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 1 matches in UniProt list
#
# [95/259] Processing: AF-P18572-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [96/259] Processing: AF-Q5SRX1-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [97/259] Processing: AF-Q9CY50-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [98/259] Processing: AF-Q99JR5-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [99/259] Processing: AF-O35459-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [100/259] Processing: AF-B2RVY9-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [101/259] Processing: AF-Q3URD3-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [102/259] Processing: AF-Q9WV91-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [103/259] Processing: AF-P39053-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [104/259] Processing: AF-Q11136-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [105/259] Processing: AF-Q9QZ23-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [106/259] Processing: AF-P61939-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [107/259] Processing: AF-P32848-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [108/259] Processing: AF-P61087-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [109/259] Processing: AF-P50518-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [110/259] Processing: AF-A2BIN1-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [111/259] Processing: AF-Q80UY1-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [112/259] Processing: AF-P70170-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 1 matches in UniProt list
#
# [113/259] Processing: AF-Q9DBP5-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [114/259] Processing: AF-Q9R0G6-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [115/259] Processing: AF-Q8BIP0-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [116/259] Processing: AF-Q60716-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [117/259] Processing: AF-Q91W29-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 1 matches in UniProt list
#
# [118/259] Processing: AF-Q8C0M9-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [119/259] Processing: AF-Q61548-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [120/259] Processing: AF-Q9D8S9-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [121/259] Processing: AF-P30416-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [122/259] Processing: AF-Q922Y1-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [123/259] Processing: AF-F8VPN4-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 1 matches in UniProt list
#
# [124/259] Processing: AF-Q8R0N6-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [125/259] Processing: AF-O35206-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [126/259] Processing: AF-Q91YN5-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [127/259] Processing: AF-P12382-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [128/259] Processing: AF-Q61233-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [129/259] Processing: AF-Q61166-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 1 matches in UniProt list
#
# [130/259] Processing: AF-Q8VCT3-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [131/259] Processing: AF-Q8CI12-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 1 matches in UniProt list
#
# [132/259] Processing: AF-Q9DCX2-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [133/259] Processing: AF-Q00896-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [134/259] Processing: AF-P97823-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [135/259] Processing: AF-P50462-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [136/259] Processing: AF-Q9DCV4-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [137/259] Processing: AF-Q9CZ30-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [138/259] Processing: AF-Q9D0C4-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [139/259] Processing: AF-Q9D7X8-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [140/259] Processing: AF-P35700-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [141/259] Processing: AF-Q8BFZ9-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [142/259] Processing: AF-Q08093-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [143/259] Processing: AF-Q9JIW9-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [144/259] Processing: AF-Q62188-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [145/259] Processing: AF-Q9QXM1-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [146/259] Processing: AF-Q8BZZ3-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [147/259] Processing: AF-Q8BYM8-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [148/259] Processing: AF-Q6PCP5-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [149/259] Processing: AF-Q6NZJ6-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [150/259] Processing: AF-Q61699-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [151/259] Processing: AF-Q9D3D9-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [152/259] Processing: AF-Q99M01-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [153/259] Processing: AF-Q8K182-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [154/259] Processing: AF-P57759-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [155/259] Processing: AF-Q9QWW1-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [156/259] Processing: AF-Q91Z31-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 1 matches in UniProt list
#
# [157/259] Processing: AF-Q6PHN9-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [158/259] Processing: AF-Q4ZJN1-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [159/259] Processing: AF-Q9DBZ1-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [160/259] Processing: AF-P70452-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [161/259] Processing: AF-Q9D710-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [162/259] Processing: AF-Q8CI70-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 1 matches in UniProt list
#
# [163/259] Processing: AF-Q99KR3-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [164/259] Processing: AF-Q91X78-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [165/259] Processing: AF-Q91V79-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [166/259] Processing: AF-Q9CQW1-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 1 matches in UniProt list
#
# [167/259] Processing: AF-Q9WV95-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [168/259] Processing: AF-P99029-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [169/259] Processing: AF-P97352-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [170/259] Processing: AF-Q91ZR2-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [171/259] Processing: AF-Q69ZN7-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [172/259] Processing: AF-Q9WUA3-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [173/259] Processing: AF-Q5SUV5-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [174/259] Processing: AF-Q9CZY3-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [175/259] Processing: AF-Q8R0P4-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [176/259] Processing: AF-Q9QYS9-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 1 matches in UniProt list
#
# [177/259] Processing: AF-Q6PHZ2-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [178/259] Processing: AF-P55772-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [179/259] Processing: AF-Q3U3R4-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [180/259] Processing: AF-Q80X95-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [181/259] Processing: AF-Q80SY6-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [182/259] Processing: AF-Q60715-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [183/259] Processing: AF-Q8BK84-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [184/259] Processing: AF-Q80VJ2-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [185/259] Processing: AF-Q99LB6-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [186/259] Processing: AF-Q8BHG2-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [187/259] Processing: AF-Q8C3X2-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [188/259] Processing: AF-O54734-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [189/259] Processing: AF-Q3UMW7-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [190/259] Processing: AF-Q8R146-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [191/259] Processing: AF-Q6NVE9-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [192/259] Processing: AF-P70236-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [193/259] Processing: AF-Q9DB60-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [194/259] Processing: AF-Q99KK7-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [195/259] Processing: AF-P54823-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 1 matches in UniProt list
#
# [196/259] Processing: AF-F8VPK0-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [197/259] Processing: AF-Q9JI99-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [198/259] Processing: AF-P50543-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [199/259] Processing: AF-P09813-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [200/259] Processing: AF-P97471-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [201/259] Processing: AF-Q5BKP2-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [202/259] Processing: AF-Q9R269-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [203/259] Processing: AF-Q7M729-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [204/259] Processing: AF-Q91VH6-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [205/259] Processing: AF-Q9R0Y5-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [206/259] Processing: AF-Q91YP2-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [207/259] Processing: AF-Q64105-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [208/259] Processing: AF-Q00898-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [209/259] Processing: AF-Q99K28-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [210/259] Processing: AF-P30677-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 1 matches in UniProt list
#
# [211/259] Processing: AF-Q571I9-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [212/259] Processing: AF-Q9JHU2-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [213/259] Processing: AF-O70475-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [214/259] Processing: AF-Q924Z4-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [215/259] Processing: AF-E9Q784-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 1 matches in UniProt list
#
# [216/259] Processing: AF-Q64727-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [217/259] Processing: AF-Q3U2P1-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [218/259] Processing: AF-Q8BVI4-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [219/259] Processing: AF-Q80Y14-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [220/259] Processing: AF-Q99J36-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [221/259] Processing: AF-Q9Z1T2-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [222/259] Processing: AF-Q9CQX2-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [223/259] Processing: AF-Q91VW3-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [224/259] Processing: AF-Q8BHE8-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [225/259] Processing: AF-Q9JK42-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [226/259] Processing: AF-Q9R111-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [227/259] Processing: AF-Q80UM7-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [228/259] Processing: AF-P09470-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [229/259] Processing: AF-Q9D6K8-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 1 matches in UniProt list
#
# [230/259] Processing: AF-Q9DCZ4-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [231/259] Processing: AF-P07758-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [232/259] Processing: AF-Q99LP6-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [233/259] Processing: AF-Q99KU0-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [234/259] Processing: AF-O35857-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [235/259] Processing: AF-Q80W37-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [236/259] Processing: AF-Q9R1S8-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [237/259] Processing: AF-E9Q777-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [238/259] Processing: AF-Q80U93-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [239/259] Processing: AF-Q8BMK4-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [240/259] Processing: AF-Q9D2M8-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [241/259] Processing: AF-P07901-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [242/259] Processing: AF-P07759-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [243/259] Processing: AF-E9QA79-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [244/259] Processing: AF-Q9ES00-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [245/259] Processing: AF-Q8BFP9-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [246/259] Processing: AF-D3Z4S3-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 1 matches in UniProt list
#
# [247/259] Processing: AF-Q64726-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [248/259] Processing: AF-P07356-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [249/259] Processing: AF-Q4VBD2-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [250/259] Processing: AF-Q8CI32-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [251/259] Processing: AF-O08917-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# [252/259] Processing: AF-P56376-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [253/259] Processing: AF-P38060-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [254/259] Processing: AF-P68037-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [255/259] Processing: AF-Q9CR16-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [256/259] Processing: AF-P62838-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [257/259] Processing: AF-P68040-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 1 matches in UniProt list
#
# [258/259] Processing: AF-G3X8U3-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [259/259] Processing: AF-Q9JL26-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 2 matches in UniProt list
#
# ======================================================================
# PROCESSING CONFIGURATION 2/2: solubility_down
# ======================================================================
# Query folder: /home/lead/notebooks/sol_down_pdb_files
# UniProt file: /home/lead/notebooks/sol_down_ids.txt
# Loaded 227 UniProt IDs
#
# Found 193 query PDB files
#
# [1/193] Processing: AF-Q99L43-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [2/193] Processing: AF-A3KFX0-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [3/193] Processing: AF-P56391-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [4/193] Processing: AF-O08547-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [5/193] Processing: AF-Q791T5-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [6/193] Processing: AF-Q9D0M1-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 9 matches in UniProt list
#
# [7/193] Processing: AF-Q9EP89-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [8/193] Processing: AF-P03977-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [9/193] Processing: AF-Q80W21-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 9 matches in UniProt list
#
# [10/193] Processing: AF-Q99JH8-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [11/193] Processing: AF-Q69ZS7-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [12/193] Processing: AF-Q99JY0-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [13/193] Processing: AF-Q61768-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [14/193] Processing: AF-P17665-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [15/193] Processing: AF-A3KMP2-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [16/193] Processing: AF-P28652-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 8 matches in UniProt list
#
# [17/193] Processing: AF-Q60634-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [18/193] Processing: AF-E9Q3L2-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [19/193] Processing: AF-O88986-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [20/193] Processing: AF-Q8C052-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [21/193] Processing: AF-O70373-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [22/193] Processing: AF-Q60823-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [23/193] Processing: AF-Q8R4R6-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [24/193] Processing: AF-Q9WTR5-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [25/193] Processing: AF-Q8BTS4-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [26/193] Processing: AF-Q8K2I3-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [27/193] Processing: AF-Q6IRU5-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [28/193] Processing: AF-Q9CQ22-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [29/193] Processing: AF-P10852-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [30/193] Processing: AF-Q3UMF0-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [31/193] Processing: AF-Q91Z40-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [32/193] Processing: AF-Q8BZ71-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [33/193] Processing: AF-Q3U5Q7-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [34/193] Processing: AF-Q9Z0J4-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [35/193] Processing: AF-Q61830-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [36/193] Processing: AF-Q61245-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [37/193] Processing: AF-P12787-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [38/193] Processing: AF-Q62230-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [39/193] Processing: AF-Q62172-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [40/193] Processing: AF-P18872-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [41/193] Processing: AF-O35678-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [42/193] Processing: AF-Q14B01-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [43/193] Processing: AF-Q6Y7W8-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [44/193] Processing: AF-P28738-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [45/193] Processing: AF-Q8BMS1-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [46/193] Processing: AF-Q8CHK3-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [47/193] Processing: AF-Q5U458-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [48/193] Processing: AF-Q8R4U6-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [49/193] Processing: AF-Q61599-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [50/193] Processing: AF-P35564-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [51/193] Processing: AF-P01863-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [52/193] Processing: AF-P49817-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [53/193] Processing: AF-P14427-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [54/193] Processing: AF-Q6PD31-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [55/193] Processing: AF-P19536-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [56/193] Processing: AF-P42225-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [57/193] Processing: AF-Q9D6U8-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [58/193] Processing: AF-P00416-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [59/193] Processing: AF-Q91VC9-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [60/193] Processing: AF-Q8C7X2-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [61/193] Processing: AF-Q9CY50-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [62/193] Processing: AF-P01867-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [63/193] Processing: AF-Q8K009-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [64/193] Processing: AF-Q8C5R8-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 10 matches in UniProt list
#
# [65/193] Processing: AF-Q3URD3-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [66/193] Processing: AF-Q923T9-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 8 matches in UniProt list
#
# [67/193] Processing: AF-Q61033-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [68/193] Processing: AF-Q60931-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [69/193] Processing: AF-Q8K2T1-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [70/193] Processing: AF-Q99KJ8-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [71/193] Processing: AF-P09690-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [72/193] Processing: AF-P48771-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [73/193] Processing: AF-Q9CPQ1-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [74/193] Processing: AF-Q8R574-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 9 matches in UniProt list
#
# [75/193] Processing: AF-Q78PY7-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [76/193] Processing: AF-P21956-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [77/193] Processing: AF-P97314-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [78/193] Processing: AF-Q99KW3-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [79/193] Processing: AF-Q9D379-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [80/193] Processing: AF-Q9D0L8-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [81/193] Processing: AF-Q91W29-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [82/193] Processing: AF-P70698-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [83/193] Processing: AF-P15626-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 9 matches in UniProt list
#
# [84/193] Processing: AF-A0A075B680-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [85/193] Processing: AF-Q60930-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [86/193] Processing: AF-Q9CQB5-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [87/193] Processing: AF-O35206-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [88/193] Processing: AF-P35288-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 1 matches in UniProt list
#
# [89/193] Processing: AF-Q6PDN3-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [90/193] Processing: AF-P51637-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [91/193] Processing: AF-Q7TT37-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [92/193] Processing: AF-Q7TPW1-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [93/193] Processing: AF-Q6PGC9-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [94/193] Processing: AF-B8QI36-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [95/193] Processing: AF-P35441-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [96/193] Processing: AF-P31750-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [97/193] Processing: AF-Q3TC33-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [98/193] Processing: AF-Q8BFZ9-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [99/193] Processing: AF-Q6P1B1-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [100/193] Processing: AF-Q91YI0-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [101/193] Processing: AF-Q08093-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [102/193] Processing: AF-Q91WC3-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [103/193] Processing: AF-Q9CS42-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 10 matches in UniProt list
#
# [104/193] Processing: AF-Q3UVL4-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [105/193] Processing: AF-Q9DC63-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [106/193] Processing: AF-Q9Z2L6-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [107/193] Processing: AF-Q6ZPY2-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [108/193] Processing: AF-Q3U186-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [109/193] Processing: AF-A0A075B5M7-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 8 matches in UniProt list
#
# [110/193] Processing: AF-P16460-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [111/193] Processing: AF-Q61703-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [112/193] Processing: AF-Q01149-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [113/193] Processing: AF-O89086-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [114/193] Processing: AF-Q8BH04-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [115/193] Processing: AF-Q6A026-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [116/193] Processing: AF-Q9DBR7-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [117/193] Processing: AF-E9PWI3-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [118/193] Processing: AF-Q9JMH9-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [119/193] Processing: AF-Q8JZN5-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 8 matches in UniProt list
#
# [120/193] Processing: AF-G3UXL2-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 10 matches in UniProt list
#
# [121/193] Processing: AF-P16015-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [122/193] Processing: AF-Q9D710-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [123/193] Processing: AF-P54071-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [124/193] Processing: AF-Q640L3-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [125/193] Processing: AF-P14873-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [126/193] Processing: AF-Q91X72-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [127/193] Processing: AF-Q8BTI9-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [128/193] Processing: AF-Q91X78-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [129/193] Processing: AF-O08788-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [130/193] Processing: AF-P01901-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [131/193] Processing: AF-P11798-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 8 matches in UniProt list
#
# [132/193] Processing: AF-O88673-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [133/193] Processing: AF-Q8C2L6-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [134/193] Processing: AF-P21107-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [135/193] Processing: AF-Q99NB1-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [136/193] Processing: AF-P97434-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [137/193] Processing: AF-Q6PHZ2-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 8 matches in UniProt list
#
# [138/193] Processing: AF-Q8BYJ6-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [139/193] Processing: AF-P17563-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [140/193] Processing: AF-P12246-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [141/193] Processing: AF-Q8CCT4-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [142/193] Processing: AF-D3Z1D3-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [143/193] Processing: AF-O35379-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [144/193] Processing: AF-Q3THG9-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [145/193] Processing: AF-Q8C3X2-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [146/193] Processing: AF-O54734-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [147/193] Processing: AF-Q6A065-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [148/193] Processing: AF-Q9CXD6-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [149/193] Processing: AF-Q64669-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [150/193] Processing: AF-O08689-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [151/193] Processing: AF-Q9D3P8-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [152/193] Processing: AF-Q8VCW8-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [153/193] Processing: AF-Q99PL6-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [154/193] Processing: AF-P09813-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [155/193] Processing: AF-Q9JHI5-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 8 matches in UniProt list
#
# [156/193] Processing: AF-Q5U430-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [157/193] Processing: AF-Q9JLQ0-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [158/193] Processing: AF-A0A075B5N3-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [159/193] Processing: AF-P19783-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [160/193] Processing: AF-Q8R079-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [161/193] Processing: AF-Q8CAQ8-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [162/193] Processing: AF-P35436-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [163/193] Processing: AF-Q3TWI9-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [164/193] Processing: AF-Q80SU7-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [165/193] Processing: AF-Q9CQX2-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [166/193] Processing: AF-P01592-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [167/193] Processing: AF-P18419-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [168/193] Processing: AF-Q64356-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [169/193] Processing: AF-Q3UMR5-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 8 matches in UniProt list
#
# [170/193] Processing: AF-Q91VN4-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [171/193] Processing: AF-Q9QXC1-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [172/193] Processing: AF-Q91V24-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [173/193] Processing: AF-Q61334-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 4 matches in UniProt list
#
# [174/193] Processing: AF-P36371-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [175/193] Processing: AF-Q62293-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [176/193] Processing: AF-O70439-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [177/193] Processing: AF-Q8BMK4-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [178/193] Processing: AF-Q8K440-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [179/193] Processing: AF-D3Z4S3-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [180/193] Processing: AF-Q8R5I6-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 9 matches in UniProt list
#
# [181/193] Processing: AF-Q8VD26-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [182/193] Processing: AF-Q8C522-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [183/193] Processing: AF-Q4VBD2-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 7 matches in UniProt list
#
# [184/193] Processing: AF-P46737-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [185/193] Processing: AF-P56716-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [186/193] Processing: AF-O89053-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [187/193] Processing: AF-O08917-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [188/193] Processing: AF-P60824-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 3 matches in UniProt list
#
# [189/193] Processing: AF-Q01853-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [190/193] Processing: AF-P58774-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 6 matches in UniProt list
#
# [191/193] Processing: AF-P11087-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [192/193] Processing: AF-Q8K0V4-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 5 matches in UniProt list
#
# [193/193] Processing: AF-P10649-F1-model_v4.pdb
#   ✓ Query complete
#   ✓ Found 9 matches in UniProt list

# %%
# ============================================================================
# CREATE SUMMARY DATAFRAMES
# ============================================================================

print("\n" + "="*70)
print("Creating summary dataframes...")

# Overall summary
summary_data = []
for dataset, query_dict in query_summary.items():
    for query_uniprot, target_counts in query_dict.items():
        for target_uniprot, count in target_counts.items():
            summary_data.append({
                'dataset': dataset,
                'query_uniprot_id': query_uniprot,
                'target_uniprot_id': target_uniprot,
                'appearance_count': count
            })

df_summary = pd.DataFrame(summary_data)
df_summary = df_summary.sort_values(['dataset', 'query_uniprot_id', 'appearance_count'], 
                                     ascending=[True, True, False])

# Create detailed results dataframe
df_detailed = pd.DataFrame(all_results)

# Save results
summary_output = "folddisco_summary.csv"
detailed_output = "folddisco_detailed_results.csv"

df_summary.to_csv(summary_output, index=False)
df_detailed.to_csv(detailed_output, index=False)

print(f"✓ Summary saved to: {summary_output}")
print(f"✓ Detailed results saved to: {detailed_output}")
# Out:
# ======================================================================
# Creating summary dataframes...
# ✓ Summary saved to: folddisco_summary.csv
# ✓ Detailed results saved to: folddisco_detailed_results.csv

# %%
# ============================================================================
# DISPLAY RESULTS
# ============================================================================

print("\n" + "="*70)
print("SUMMARY STATISTICS")
print("="*70)

for config in QUERY_CONFIGS:
    label = config['label']
    dataset_summary = df_summary[df_summary['dataset'] == label]
    dataset_detailed = df_detailed[df_detailed['dataset'] == label]
    
    print(f"\n{label}:")
    print(f"  Total queries processed: {len(dataset_summary['query_uniprot_id'].unique())}")
    print(f"  Total unique target proteins found: {len(dataset_summary['target_uniprot_id'].unique())}")
    print(f"  Total matches recorded: {len(dataset_detailed)}")

print("\n" + "="*70)
print("TOP 10 MOST FREQUENT TARGET PROTEINS (across all datasets)")
print("="*70)
top_targets = df_summary.groupby('target_uniprot_id')['appearance_count'].sum().sort_values(ascending=False).head(10)
print(top_targets)

print("\n" + "="*70)
print("SAMPLE OF SUMMARY DATAFRAME")
print("="*70)
print(df_summary.head(20))

# Return the dataframes for further analysis
print("\n✓ Complete! DataFrames available as: df_summary, df_detailed")
# Out:
# ======================================================================
# SUMMARY STATISTICS
# ======================================================================
#
# solubility_up:
#   Total queries processed: 259
#   Total unique target proteins found: 259
#   Total matches recorded: 768
#
# solubility_down:
#   Total queries processed: 193
#   Total unique target proteins found: 193
#   Total matches recorded: 1167
#
# ======================================================================
# TOP 10 MOST FREQUENT TARGET PROTEINS (across all datasets)
# ======================================================================
# target_uniprot_id
# E9Q3L2    174
# Q91V24    172
# Q80SU7    171
# F8VPN4    144
# Q5U430    141
# Q8K440    119
# P70170     98
# Q69ZN7     60
# O35379     42
# Q9JMH9     33
# Name: appearance_count, dtype: int64
#
# ======================================================================
# SAMPLE OF SUMMARY DATAFRAME
# ======================================================================
#               dataset query_uniprot_id target_uniprot_id  appearance_count
# 1425  solubility_down       A0A075B5M7        A0A075B5M7                 1
# 1426  solubility_down       A0A075B5M7        A0A075B5N3                 1
# 1427  solubility_down       A0A075B5M7            P03977                 1
# 1428  solubility_down       A0A075B5M7            Q62230                 1
# 1429  solubility_down       A0A075B5M7        A0A075B680                 1
# 1430  solubility_down       A0A075B5M7            Q6PDN3                 1
# 1431  solubility_down       A0A075B5M7            Q80SU7                 1
# 1432  solubility_down       A0A075B5M7            Q91V24                 1
# 1724  solubility_down       A0A075B5N3        A0A075B5N3                 1
# 1725  solubility_down       A0A075B5N3        A0A075B5M7                 1
# 1726  solubility_down       A0A075B5N3            P03977                 1
# 1727  solubility_down       A0A075B5N3            Q62230                 1
# 1728  solubility_down       A0A075B5N3        A0A075B680                 1
# 1729  solubility_down       A0A075B5N3            Q6PDN3                 1
# 1730  solubility_down       A0A075B5N3            Q5U430                 1
# 1275  solubility_down       A0A075B680        A0A075B680                 1
# 1276  solubility_down       A0A075B680            Q62230                 1
# 1277  solubility_down       A0A075B680            Q6PDN3                 1
# 1278  solubility_down       A0A075B680        A0A075B5N3                 1
# 1279  solubility_down       A0A075B680        A0A075B5M7                 1
#
# ✓ Complete! DataFrames available as: df_summary, df_detailed
